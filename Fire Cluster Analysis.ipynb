# %%
Output = '/Users/alexis/Library/CloudStorage/OneDrive-UniversityofNorthCarolinaatChapelHill/CEMALB_DataAnalysisPM/Projects/P1015. Fire Sufficient Similarity/P1015.3. Analyses/P1015.3.3. Cluster Analysis/Output'

library(readxl)
library(tidyverse)
library(reshape2)
library(factoextra)
library(gridExtra)
library(ggrepel)
library(pheatmap)

# reading in file
weight_df = data.frame(read_excel("Input/Processed_Weight_Data_030525.xlsx"))
volume_df = data.frame(read_excel("Input/Processed_Volume_Data_030525.xlsx"))

# %%
head(weight_df)
# Out:
#   HAWC_ID Metric Data Study              Replicate Chemical_Class DTXSID
# 1 271638  Weight WS   Jalava et al. 2012 1         PAH            DTXSID3021774
# 2 271638  Weight WS   Jalava et al. 2012 1         PAH            DTXSID4075459
# 3 271638  Weight WS   Jalava et al. 2012 1         PAH            DTXSID8052691
# 4 271638  Weight WS   Jalava et al. 2012 1         Metal          Ca
# 5 271638  Weight WS   Jalava et al. 2012 1         PAH            DTXSID5047740
# 6 271638  Weight WS   Jalava et al. 2012 1         PAH            DTXSID6062591
#   Name                 Value
# 1 Acenaphthene          132.7
# 2 Benzo(c)phenanthrene  493.9
# 3 Benzo(j)fluoranthene  617.3
# 4 Ca                   1140.0
# 5 Coronene               75.5
# 6 Cyclopenta(cd)pyrene 1067.0

# %% [markdown]
# This analysis will use PCA to explore if chemical and metal concentrations of wildfire and woodsmoke samples are similar using PCA.
#
# # Principal Component Analysis (PCA)

# %%
# casting wide
weight_df %>%
    # creating sample ids
    unite("SampleID", c(colnames(weight_df)[c(3,1,6,7)]), remove = FALSE) %>%
    # averaging to get rid of replicates
    group_by(HAWC_ID, Name) %>%
    mutate(Avg_Value = mean(Value)) %>%
    select(-c("Replicate", "Value")) %>%
    unique() %>%
    pivot_wider(names_from = "HAWC_ID", values_from = "Avg_Value") #%>%
    #column_to_rownames(var = "SampleID")
# Out:
#     SampleID                     Metric Data Study
# 1   WS_271638_PAH_DTXSID3021774  Weight WS   Jalava et al. 2012
# 2   WS_271638_PAH_DTXSID4075459  Weight WS   Jalava et al. 2012
# 3   WS_271638_PAH_DTXSID8052691  Weight WS   Jalava et al. 2012
# 4   WS_271638_Metal_Ca           Weight WS   Jalava et al. 2012
# 5   WS_271638_PAH_DTXSID5047740  Weight WS   Jalava et al. 2012
# 6   WS_271638_PAH_DTXSID6062591  Weight WS   Jalava et al. 2012
# 7   WS_271638_PAH_DTXSID3024104  Weight WS   Jalava et al. 2012
# 8   WS_271638_Metal_K            Weight WS   Jalava et al. 2012
# 9   WS_271638_Metal_Mg           Weight WS   Jalava et al. 2012
# 10  WS_271638_Metal_Mn           Weight WS   Jalava et al. 2012
# 11  WS_271638_PAH_DTXSID6024254  Weight WS   Jalava et al. 2012
# 12  WS_271638_PAH_DTXSID9059757  Weight WS   Jalava et al. 2012
# 13  WS_271638_Metal_Zn           Weight WS   Jalava et al. 2012
# 14  WS_271769_PAH_DTXSID3021774  Weight WS   Uski et al. 2012
# ...
